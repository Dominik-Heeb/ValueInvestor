# %% [markdown]
# # TOC and index
#
# 2022 01 01
#
# __Description:__
# * This notebook renames all notebook located in the same folder so that the numbering becomes continuous. The step size can be set in `cintStep`.
# * Additionally, a table of contents (TOC) and an index are created.

# %%
# own libraries
import Utilities as u
import MachineLearning as ml

# activate changes in libraries
import importlib
importlib.reload(u)
importlib.reload(ml)

# aliases
from Utilities import TypeChecker as t
from Utilities import PrintAlias as p

# %% [markdown]
# ## Goal
# * This Jupyter notebook lists all the notebooks of the projects: __table of contents__ or TOC.
# * Furthermore, a raw __index__ is extracted:
#     * words that are not common to all (or most) of the notebooks.
#     * words without digits, underscores and camel-case.
# * This notebook __re-numbers__ the notebooks
#     * in strides of 1: final version.
#     * in strides of 2: to make insertions easy during development.

# %%
import re
def WithoutAttachments(strSource):
    strSource = strSource.replace("\n", " ")
    return re.sub(r'"attachments":.*?}', "", strSource) # ? meaning non-greedy
if False:
    strTester =     '''
       before
       "attachments": {
        "a3e2149a-747f-41e8-a98a-3d13ad17d598.png": {
         "image/png": "iVBORw0KGgoAAAANSUhEUgAABAgUKFChQoECBAgUKnhOonzUB
        } after
    '''
    print(WithoutAttachments(strTester))

# %%
# get names of Jupyter notebooks
import os
import sys
import re
strDirectory = os.path.abspath(os.getcwd())
lstrFilenames = []
for strFilename in os.listdir(strDirectory):
    if strFilename.endswith(".ipynb") and not "index" in strFilename and not "Heeb" in strFilename:
        lstrFilenames.append(strFilename)
lstrFilenames.sort()

# cut current numbers
lstrFilenamesWithoutNumbers = []
for strFilename in lstrFilenames:
    lstrFilenamesWithoutNumbers.append(re.sub(r"^\d\d *", '', strFilename)) 

# create new numbers
if False: # productive
    cintStep = 1
else:
    cintStep = 2 # 2 allows for manual insertion of new notebooks
intNumber = cintStep
lstrFilenamesWithNewNumbers = []
lintNewNumbers = []
for strFilename in lstrFilenamesWithoutNumbers:
    lstrFilenamesWithNewNumbers.append(str(intNumber).zfill(2) + " " + strFilename)
    lintNewNumbers.append(intNumber)
    intNumber += cintStep

# rename
for intPointer,strOriginalFilename in enumerate(lstrFilenames):
    strNewFilename = lstrFilenamesWithNewNumbers[intPointer]
    os.rename(strOriginalFilename, strNewFilename)

# collect words, drop numbers
# create sets of chapter numbers for each word
dsintChapters = {} # dictionary of sets
print("Table of contents (TOC) ------------------------------".upper())
print()
for intPointer,strFilenameWithNewNumbers in enumerate(lstrFilenamesWithNewNumbers):
    print(strFilenameWithNewNumbers)
    intChapter = lintNewNumbers[intPointer]
    with open(strFilenameWithNewNumbers,encoding="utf-8") as objTextIOWrapper:
        strContents = objTextIOWrapper.read()
        strContents = WithoutAttachments(strContents)        
        lstrWords = re.findall(r"[\w']+|[;]", strContents)
        if False:
            lstrWords = lstrWords[:10]
        for strWord in lstrWords:
            strWord = strWord.replace("'", "")
            if not u.DoesContainDigits(strWord): 
                if not u.DoesContainUnderscore(strWord):
                    if not u.IsCamelCase(strWord):
                        try:
                            # consecutive entry
                            sintChapters = dsintChapters[strWord]
                            sintChapters.add(intChapter)
                            dsintChapters[strWord] = sintChapters
                        except:
                            # first entry
                            sintChapters = {intChapter}
                            dsintChapters[strWord] = sintChapters

# remove frequent entries
cfltProportionAllowed = 0.6
intEntriesAllowed = round(len(lstrFilenames) * cfltProportionAllowed)
dsintChaptersFrequentEntries = {}
for strWord in dsintChapters.keys():
    if len(dsintChapters[strWord]) <= intEntriesAllowed:
        dsintChaptersFrequentEntries[strWord.lower()] = dsintChapters[strWord]
     
# sort index by key
import collections
objOrderedDict = collections.OrderedDict(sorted(dsintChaptersFrequentEntries.items()))

# print index
print() 
print("Index -----------------------------------------------".upper())
print() 
for strWord, sintChapters in objOrderedDict.items():
    lintChapters = list(sintChapters)
    lintChapters.sort()
    lstrChapters = [str(intChapter) for intChapter in lintChapters] 
    print(f"{strWord}:" , ', '.join(lstrChapters))
# Out:
# TABLE OF CONTENTS (TOC) ------------------------------
#
# 02 dh Project Task.ipynb
# 04 dh Load data.ipynb
# 06 dh EDA.ipynb
# 08 dh Differencing.ipynb
# 10 dh Reduction 2020 - 2023.ipynb
# 12 dh Dummy prediction.ipynb
# 14 dh L2 regression.ipynb
# 16 dh ARIMA and SARIMA.ipynb
# 18 dh Prophet.ipynb
# 20 dh Info dump.ipynb
# 22 dh xxx.ipynb
#
# INDEX -----------------------------------------------
#
# : 4, 6, 8, 10, 12, 14, 16
# ;: 4, 6, 8, 10, 12, 14, 16
# a: 4, 6, 8, 10, 12, 14, 16
# aa: 10
# aaa: 16
# aaaaagv: 10
# abbreviation: 16
# abbreviations: 6
# abiv: 16
# abk: 14
# able: 16
# about: 4, 6, 16
# above: 4, 16
# abs: 14
# absolute: 14
# abwr: 10
# ac: 10
# according: 4
# accumulate: 14
# act: 14
# actions: 4
# actually: 4
# adapted: 4
# add: 16
# added: 16
# adding: 12
# adf: 16
# adfuller: 16
# adjust: 16
# adjustment: 16
# advancinganalytics: 20
# ae: 14
# af: 8
# afg: 8
# after: 16
# ag: 14
# against: 4
# agf: 16
# ah: 8
# ai: 16
# aic: 16
# aid: 2
# ail: 10
# ak: 6
# al: 14
# algorithms: 20
# align: 4, 6, 8, 10, 12, 14, 16
# all: 6, 14, 16
# allowing: 4
# alpha: 16
# already: 10
# also: 10, 16
# alternatives: 14
# am: 14, 16
# ama: 14
# amhnnw: 14
# among: 4
# an: 4, 14
# analyses: 6
# analysis: 14, 16
# analyticsindiamag: 16
# analyze: 16
# analyzed: 16
# anq: 10
# anz: 12
# ao: 16
# ap: 8
# apo: 12
# append: 12, 16
# applied: 16
# apply: 16
# applying: 16
# aq: 16
# aqv: 16
# aqy: 16
# ar: 16
# are: 2, 4, 6, 8, 10, 14, 16
# argument: 4
# arima: 16
# arma: 16
# around: 2, 6
# array: 14
# arrays: 14
# artificial: 16
# as: 14
# asb: 16
# ash: 12
# asset: 4
# at: 16
# atf: 6
# attachment: 2, 14, 20
# au: 14, 16
# augmented: 16
# auhfjqnbojp: 16
# auto: 16
# autolag: 16
# autoregression: 16
# autoregressive: 16
# av: 16
# available: 4
# average: 16
# avh: 8
# avw: 10
# aw: 14
# awem: 16
# awr: 16
# awv: 16
# ax: 8
# axes: 6, 8, 10, 12, 14, 16
# axi: 10
# axis: 4, 16
# axvline: 10, 12, 14, 16
# axx: 10
# axy: 16
# ay: 8
# ayq: 14
# az: 16
# azn: 6
# b: 6, 8, 10, 12, 14, 16
# balance: 4
# bands: 2
# bar: 14
# based: 2, 16
# basg: 14
# basis: 2
# bbg: 16
# bbz: 16
# bces: 10
# bde: 16
# bdpqa: 16
# bea: 8
# because: 4
# become: 14, 16
# before: 4, 14, 16
# believes: 4
# below: 16
# best: 14
# between: 4, 8, 12, 14
# bf: 16
# bfab: 6
# bfc: 6
# bfd: 16
# bfnq: 6
# bga: 8
# bgg: 16
# bhp: 16
# bhq: 14
# bi: 10, 16
# bigger: 4
# biggest: 6
# binary: 6, 8, 10, 12, 14, 16
# bins: 6
# bj: 16
# bjk: 16
# bka: 14
# bkc: 16
# bkf: 14
# black: 12, 14, 16
# blog: 20
# blue: 6, 12, 14, 16
# bm: 8
# bmu: 14
# bn: 8
# bnv: 6
# bo: 12
# bollinger: 2
# border: 4, 6, 8, 10, 12, 14, 16
# both: 12, 16
# bp: 8, 16
# bq: 8
# bra: 14
# brjo: 6
# brm: 8
# brown: 16
# bt: 16
# btw: 16
# bu: 14
# bus: 16
# but: 4, 12, 14
# buy: 2
# buying: 2
# bv: 14
# bvdo: 16
# bw: 16
# bwa: 16
# bwmfv: 14
# bwt: 16
# bx: 16
# bxg: 12
# bxhk: 16
# bxrc: 10
# by: 6, 8, 16
# bya: 16
# byv: 14
# bzh: 6
# c: 6, 8, 10, 14, 16
# ca: 6, 8
# cagleu: 10
# calculated: 10
# calculates: 16
# calculating: 12
# calculation: 16
# call: 4
# called: 16
# calls: 4
# can: 4, 14, 16
# capital: 2
# cash: 4
# cashflow: 4
# cax: 14
# cayaaad: 10
# cb: 12
# cbg: 8
# cbjbj: 16
# cc: 10, 16
# ccc: 8
# cce: 16
# ccs: 8
# ce: 6
# cf: 16
# cff: 16
# cfffdx: 16
# cgd: 16
# chain: 4
# change: 4
# characterizing: 2
# chart: 2, 14
# check: 16
# checks: 16
# chi: 12
# chy: 10
# cj: 16
# cjo: 16
# cl: 16
# cle: 12
# cljp: 14
# close: 6
# clvvgwx: 10
# cmcpagd: 10
# cmo: 16
# cn: 8, 16
# cnm: 12
# co: 20
# coefficient: 14
# coefficients: 14
# color: 6, 8, 10, 12, 14, 16
# colors: 6
# column: 4
# columns: 6
# com: 2, 16, 20
# companies: 2
# company: 4
# companys: 4
# comparatively: 10
# compared: 10
# compatibility: 16
# comprehension: 16
# comprehensive: 16
# considered: 12
# constant: 16
# constantly: 12
# contain: 14
# contains: 4
# contents: 4
# continue: 6
# convert: 14
# converted: 8, 12
# copy: 4, 6, 8, 10, 12, 14, 16
# core: 4
# correlated: 6
# correlating: 6
# correlations: 6
# count: 4
# countries: 4
# country: 2, 4, 6
# counts: 6
# coursera: 20
# covers: 10
# covid: 4, 8
# cp: 10
# cq: 10
# cr: 10
# create: 14, 16
# created: 4, 8, 10, 12, 14, 16
# crh: 14
# ql: 8, 10
# qlo: 12
# qm: 16
# qn: 8
# qnv: 6
# qo: 16
# qoly: 6
# qoy: 8
# qp: 16
# qpt: 10
# qqq: 14
# qqs: 10
# qr: 16
# qs: 16
# qsd: 14
# qt: 12
# qta: 8
# qtl: 16
# qu: 10, 16
# quantity: 4
# quarter: 12
# quarterly: 2
# quarters: 4
# quick: 16
# qv: 8, 16
# qvweb: 16
# qwof: 16
# qx: 14
# qxf: 16
# qyi: 16
# qyt: 16
# qz: 16
# r: 6, 8, 10, 12, 14, 16
# ra: 10
# rac: 10
# random: 16
# range: 8, 10, 12, 14, 16
# rather: 10
# raw: 12
# rb: 6, 8, 10, 12, 14, 16
# rby: 10
# rct: 16
# rd: 12
# re: 16
# reached: 6
# read: 20
# real: 16
# reasonable: 4, 14, 16
# recommend: 2
# recommended: 4
# record: 14
# records: 6, 14
# red: 6, 10, 12, 14, 16
# reduction: 10
# ref: 6
# refer: 6
# regression: 14, 16
# regressive: 16
# reindex: 6, 8
# relatively: 6, 10
# relevant: 4
# remember: 16
# remqt: 14
# rename: 6, 16
# report: 16
# reshape: 14
# rest: 6
# restored: 10
# result: 6, 14, 16
# resulting: 16
# results: 12, 14, 16
# return: 4, 8, 12, 14, 16
# returns: 4
# rexp: 8
# rf: 6
# rhgd: 10
# rhulk: 10
# ri: 10
# ridge: 14
# right: 4, 6, 8, 10, 12, 14, 16
# rise: 4
# rj: 16
# rl: 8, 16
# rlp: 16
# rm: 16
# rmse: 12, 14
# rough: 12
# round: 12, 14, 16
# rows: 4, 6, 8, 10, 12, 14, 16
# roxo: 8
# rq: 16
# rqb: 8
# rqgt: 16
# rr: 12, 16
# rrtx: 14
# rs: 16
# rsd: 16
# rsplit: 4
# rt: 10
# rtl: 16
# ru: 8, 10
# run: 14, 16
# runs: 14
# rvm: 16
# rx: 14
# rxs: 6
# ryd: 8
# rz: 10
# s: 6, 8, 10, 12, 14, 16
# sam: 10
# sandeep: 4
# sarima: 16
# sarimax: 16
# saturday: 6
# saturdays: 6
# save: 4
# sby: 8
# sbz: 8
# sc: 16
# scale: 4, 8, 12
# scatter: 6, 10, 12, 14
# scattergram: 10
# scatterplot: 6
# scoped: 4, 6, 8, 10, 12, 14, 16
# scoring: 14
# screenshot: 14
# sd: 16
# seaborn: 6
# search: 14
# seasonal: 8
# seasonality: 16
# seasons: 16
# seconds: 16
# securities: 4
# see: 16
# seem: 4, 16
# seems: 4, 10, 16
# sejltm: 8
# sell: 4
# selling: 2
# sense: 4, 6
# sep: 10
# separates: 10, 12, 14
# separating: 10, 12, 14
# separator: 10, 12, 14
# serialized: 4
# series: 6, 8, 10, 12, 14, 16, 20
# set: 2, 6, 14
# sets: 14, 16
# several: 6
# sezpxuo: 16
# sf: 8
# sfj: 10
# sg: 16
# sh: 10
# shape: 4, 6, 14, 16
# share: 4, 6
# sharecount: 4
# sharing: 2
# sheet: 4
# sheets: 2
# shgz: 8
# shifted: 14
# short: 16
# shorten: 14
# should: 2
# show: 4, 8
# shu: 16
# shuffle: 14
# si: 8
# similar: 6
# simply: 12
# simulated: 16
# simulations: 16
# single: 4
# size: 6, 8, 10, 12, 14, 16
# sj: 16
# skew: 6
# skewed: 6
# sklearn: 14
# sm: 16
# small: 10
# smoothing: 16
# snn: 6
# sns: 14
# so: 8
# solved: 2, 6, 18, 20, 22
# somewhat: 4
# sos: 10
# sov: 16
# sow: 10
# sp: 16
# special: 20
# specific: 4
# specified: 4
# split: 2, 14, 16
# splits: 4
# spn: 16
# spreadsheets: 2
# sqrt: 12, 14
# sqt: 10
# sr: 6
# sre: 12
# sricharan: 4
# ssc: 10
# ssm: 10
# ssp: 16
# st: 16
# stable: 6
# standard: 10, 16
# stands: 16
# start: 4, 8, 16
# startswith: 4
# statement: 4
# stationarity: 16
# stationary: 16
# statistical: 2
# statsmodels: 16
# stattools: 16
# stay: 16
# std: 10
# stdout: 4, 6, 8, 10, 12, 14, 16
# step: 16
# stock: 10, 12, 14
# stocks: 2, 4
# stopper: 4
# str: 4
# strategies: 4
# stream: 4, 6, 8, 10, 12, 14, 16
# streamline: 4
# strftime: 6
# strike: 4
# strong: 6, 10
# strptime: 6, 16
# style: 4, 6, 8, 10, 12, 14, 16
# substantial: 6
# subtract: 16
# such: 4
# suf: 6
# summary: 16
# sunday: 6
# sundays: 6
# suppresses: 4
# sure: 14
# svg: 8
# sw: 16
# sx: 14, 16
# sxe: 16
# sxlp: 10
# syngenta: 4
# syra: 16
# systems: 2
# syt: 4
# sz: 6
# t: 6, 8, 10, 12, 14, 16
# ta: 8
# table: 4, 6, 8, 10, 12, 14, 16
# takes: 16
# targets: 2
# task: 2
# taxjnvu: 10
# tb: 16
# tbody: 4, 6, 8, 10, 12, 14, 16
# tci: 10
# tcz: 16
# td: 4, 6, 8, 10, 12, 14, 16
# te: 16
# tends: 12
# terms: 16
# test: 16
# testing: 2, 10, 14
# tf: 16
# th: 6
# than: 10, 14
# that: 10, 16
# the: 4
# thead: 4, 6, 8, 10, 12, 14, 16
# them: 4
# then: 16
# there: 6, 10
# these: 10
# they: 16
# this: 8, 10, 12, 16, 20
# those: 16
# through: 14
# thursday: 6, 8
# thus: 10, 14
# ti: 16
# ticker: 4
# ticks: 6
# time: 8, 10, 12, 14, 16, 20
# timedelta: 12, 14
# timeseries: 20
# timestamps: 10, 12, 14
# title: 6, 8, 14, 16
# tj: 16
# tk: 8
# tka: 16
# tkp: 8
# tktt: 16
# tl: 16
# tn: 8
# tnsg: 6
# to: 16
# together: 6
# too: 14, 16
# top: 4, 6, 8, 10, 12, 14, 16
# total: 4
# tp: 16
# tpdn: 16
# tr: 4, 6, 8, 10, 12, 14, 16
# trade: 2
# trading: 2, 4
# train: 16
# training: 12
# transformation: 6
# trend: 8, 10, 16
# true: 12, 14
# try: 4
# ts: 16
# tsa: 16
# tsj: 6
# tt: 16
# ttb: 14
# ttx: 10
# tuesday: 6, 8
# tum: 16
# tuple: 4
# turned: 4
# tutorial: 16
# tva: 16
# tvb: 16
# tvi: 12
# tvp: 8
# tw: 16
# twl: 10
# two: 16
# twwf: 8
# txf: 16
