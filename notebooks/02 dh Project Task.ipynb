# %% [markdown]
# # Project task
#
# Apziva project #5: ValueInvestor<br>
# 2023 09 04
#
# __Summary:__
# * This notebook describes the task to be solved.

# %% [markdown]
# ## TOC: <a class="anchor" id="TOC"></a>
# * [Utilities](#Utilities)
# * [Task description](#TaskDescription)

# %% [markdown]
# ## Utilities <a class="anchor" id="Utilities"></a>
# [TOC](#TOC)

# %%
# own libraries
import Utilities as u
import MachineLearning as ml

# activate changes in libraries
import importlib
importlib.reload(u)
importlib.reload(ml)

# aliases
from Utilities import TypeChecker as t
from Utilities import PrintAlias as p

# %% [markdown]
# ## Task description <a class="anchor" id="TaskDescription"></a>
# [TOC](#TOC)

# %% [markdown]
# __Background__
# * We are a __portfolio investment company__ and we make investments in the emerging markets around the world. Our company profits by investing in profitable companies, buying, holding and selling company stocks based on value investing principles.
# * Our goal is to establish a __robust intelligent system__ to aid our value investing efforts __using stock market data__.
# * We make __investment decisions__ based on __intrinsic value of companies__ and do not trade on the basis of daily market volatility.
# * Our profit __realization strategy__ typically involves __weekly, monthly and quarterly performance of stocks__ we buy or hold.
#
# __Data Description__
# * You are given a set of __portfolio companies trading data__ from emerging markets including __stock prices__ for:
#     * 2020 Q1-Q2-Q3-Q4
#     * 2021 Q1
# * Each company stock is provided in different sheets.
# * Each market's __operating days vary__ based on
#     * the country of the company
#     * the market the stocks are exchanged
# * Data split:
#     * 2020: training/validation.
#     * 2021: testing.
#
# __Download Data:__
# https://docs.google.com/spreadsheets/d/1MiunF_O8eNWIcfaOA4PVm668RN7FgLNA0a6U4LWf5Bk/edit?usp=sharing
#
# __Goals__
# * __Predict stock price valuations__. Basis:
#     * daily
#     * weekly
#     * monthly
# * Recommend __decisions__:
#     * BUY
#     * HOLD
#     * SELL
# * Targets:
#     * __Maximize capital returns__.
#     * Minimize losses (ideally a loss should never happen).
#     * __Minimize HOLD period__.
#
# __Success Metrics__
# * Evaluate on the basis of __capital returns__.
# * Use Bollinger Bands to measure your systems effectiveness.

# %% [markdown]
# __Comments__
# * Bollinger Bands (/ˈbɒlɪndʒər/) are a type of statistical chart characterizing the __prices and volatility over time__ of a financial instrument.
# * Bollinger Bands use a formulaic method propounded by __John Bollinger__ in the __1980s__.

# %% [markdown]
# ![image.png](attachment:d92c2ff6-ee9d-4a9a-8695-124220ea4e7f.png)
